# %% [markdown]
# # Getting the possible locations from the companies dataset

# %%
from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient()
db = client.get_database("companies")
comp = db.companies

# %% [markdown]
# ### Considerations:
# - We need to divide the offices dictionaries in its different offices using unwind so we have one single coordinate in each document.
# - We should eliminate the null values.
# - Our data should look like this in order to extract the locations:
# ```python
# {
#     "type": "Point",
#     "coordinates": [125.6, 10.1] # LONG, LAT
# }
#
# ```

# %%
res = comp.aggregate([
                      {"$unwind":"$offices" },
                      {"$match":{"offices.latitude":{"$ne":None}}},
                      {"$match":{"offices.longitude":{"$ne":None}}},
                      {"$project":{"_id":0}} 
                     ])

# %%
db.companies_unwinded.insert_many(res)

# %%
offices = db.companies_unwinded

# %%
res = offices.find( {"offices.country_code":"USA"})
len(list(res))
# Out:
# 7600

# %%
number_of_offices = 7600

# %% [markdown]
# 7600 of those unwinded companies are located in the USA, that means that **we have 7600 offices locations to choose.**

# %% [markdown]
#  We want our location to follow the geojson format, so let's convert it.

# %% [markdown]
# *This is the office attribute.*

# %%
res = offices.find( {}, {"offices":1})
list(res.limit(1))
# Out:
# [{'_id': ObjectId('5fb00ed5a020aa91fd9251a2'),
#   'offices': {'description': '',
#    'address1': '710 - 2nd Avenue',
#    'address2': 'Suite 1100',
#    'zip_code': '98104',
#    'city': 'Seattle',
#    'state_code': 'WA',
#    'country_code': 'USA',
#    'latitude': 47.603122,
#    'longitude': -122.333253}}]

# %% [markdown]
# *This is the coord (geojson) and office attribute.*

# %%
res = offices.find({},{"offices":1})
for c in res:
    filt = {"_id":c["_id"]}
    coord = {
              "type": "Point",
              "coordinates": [c["offices"]["longitude"], c["offices"]["latitude"]]
            }
    update = {"$set":{"coord":coord}}
    offices.update_one(filt,update)

# %%
res = offices.find( {}, {"offices":1, "coord":1})

# %%
list(res.limit(1))
# Out:
# [{'_id': ObjectId('5fb00ed5a020aa91fd9251a2'),
#   'offices': {'description': '',
#    'address1': '710 - 2nd Avenue',
#    'address2': 'Suite 1100',
#    'zip_code': '98104',
#    'city': 'Seattle',
#    'state_code': 'WA',
#    'country_code': 'USA',
#    'latitude': 47.603122,
#    'longitude': -122.333253},
#   'coord': {'type': 'Point', 'coordinates': [-122.333253, 47.603122]}}]

# %% [markdown]
# **Now we can use this database to find companies near a certain point, list of points, polygon...**

# %% [markdown]
# [https://docs.mongodb.com/manual/reference/operator/query/near/](https://docs.mongodb.com/manual/reference/operator/query/near/)

# %% [markdown]
# We have found out that there are 7600, locations in the USA. Let's see where are they.

# %%
res = offices.find( {"offices.country_code":"USA"}, {"offices.state_code":1})

# %%
states = [res[i]['offices']['state_code'] for i in range(number_of_offices)]

# %% [markdown]
# ## Offices by state

# %% [markdown]
# The amount of offices in California is much bigger that the amount of offices in the rest of the country. However, in a second position we have New York and, even though it has a lot less offices, it could also be a good location for our office.

# %%
df = pd.DataFrame(columns = ['states'])
df.states = states
df.states.value_counts().head(4)
# Out:
# CA    2968
# NY     774
# MA     451
# TX     386
# Name: states, dtype: int64

# %% [markdown]
# ## Offices by state in the game_video category

# %% [markdown]
# Let's study another parameter, in which state there are most companies in the game_video category so we can be close to out competitors and learn from them.

# %%
res = offices.find( {"offices.country_code":"USA", "category_code": "games_video"}, {"offices.state_code":1})
states = [res[i]['offices']['state_code'] for i in range(464)]

# %%
df = pd.DataFrame(columns = ['states'])
df.states = states
df.states.value_counts().head(4)
# Out:
# CA    220
# NY     65
# WA     23
# MA     18
# Name: states, dtype: int64

# %% [markdown]
#  # Our company will be located in California

# %% [markdown]
# ### We have a lot more data to compare and it is the state with the higuest number of gaming companies. Let's save this information in a DataFrame.

# %% [markdown]
# If we select USA and CA, there are some points outside california that are also in the set, so I selected CA using the map in mongo  compass.

# %%
filter_q = {"coord.coordinates": {"$geoWithin": { "$geometry": { "type": "Polygon", "coordinates": [ [ [ -123.36526329703172, 38.411863094210894 ], [ -120.9940831325274, 34.66747439969875 ], [ -117.07724646425912, 32.27570902526987 ], [ -116.35711228118673, 32.67643502670626 ], [ -120.11586875309942, 39.54695688156478 ], [ -123.36526329703172, 38.411863094210894 ] ] ] }}}}
project_q = {"name":1, "coord":1,"offices.address1":1}
res = offices.find(filter_q, project_q)

# %%
len(list(res))
# Out:
# 2925

# %%
name = []
address = []
long_lat = []
for i in range(2925):
    name.append(res[i]['name'])
    address.append(res[i]['offices']['address1'])
    long_lat.append(res[i]['coord']['coordinates'][::-1])

# %%
df = pd.DataFrame()
df['name'] = name
df['adress'] = address
df['long_lat'] = long_lat
df
# Out:
#                  name                      adress                    long_lat
# 0           AdventNet            4900 Hopyard Rd.    [37.692934, -121.904945]
# 1                Zoho             4900 Hopyard Rd    [37.692934, -121.904945]
# 2                Digg          135 Mississippi St    [37.764726, -122.394523]
# 3            Facebook            1601 Willow Road     [37.41605, -122.151801]
# 4             Postini  959 Skyway Road, Suite 200    [37.506885, -122.247573]
# ...               ...                         ...                         ...
# 2920         Purfresh           1350 Willow Road,    [37.477008, -122.151599]
# 2921        MyChances                              [37.4484914, -122.1802812]
# 2922  InSound Medical          39660 Eureka Drive    [37.512038, -121.998513]
# 2923          Intergy      11875 Dublin Boulevard  [37.7019395, -121.9366984]
# 2924    Willdan Group    2401 East Katella Avenue    [33.806525, -117.882314]
#
# [2925 rows x 3 columns]

# %% [markdown]
# # After the research we are going to locate our office in Los Angeles

# %%
offices = db.companies_unwinded
filter_q = {'offices.country_code': 'USA','offices.state_code': 'CA','offices.city': 'Los Angeles' }
project_q = {"name":1, "coord":1,"offices.address1":1}
res = offices.find(filter_q, project_q)

# %%
list(res)
# Out:
# [{'_id': ObjectId('5fb00ed5a020aa91fd9251b4'),
#   'name': 'Helio',
#   'offices': {'address1': '10960 Wilshire Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.446596, 34.057498]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925202'),
#   'name': 'Stickam',
#   'offices': {'address1': '1975 pads rd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.254558, 34.051409]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925227'),
#   'name': 'TripUp',
#   'offices': {'address1': None},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92528c'),
#   'name': 'ScanScout',
#   'offices': {'address1': '11601 Wilshire Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.459995, 34.050887]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9252d4'),
#   'name': 'WebbAlert',
#   'offices': {'address1': None},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9252f8'),
#   'name': 'Revver',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9252fd'),
#   'name': 'Social Platform',
#   'offices': {'address1': '7195 Hollywood Boulevard, Ste. 874'},
#   'coord': {'type': 'Point', 'coordinates': [-118.327071, 34.101617]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92535c'),
#   'name': 'DAVE Networks',
#   'offices': {'address1': '5301 Beethoven Street'},
#   'coord': {'type': 'Point', 'coordinates': [-118.423423, 33.979033]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925362'),
#   'name': 'Shopzilla',
#   'offices': {'address1': '12200 W. Olympic Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9253a6'),
#   'name': 'PriceGrabber',
#   'offices': {'address1': '4859 W. Slauson Ave. #259'},
#   'coord': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9253be'),
#   'name': 'hulu',
#   'offices': {'address1': '12312 W. Olympic Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.456806, 34.031276]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9253d5'),
#   'name': 'Orgoo',
#   'offices': {'address1': '11022 Santa Monica Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.4419012, 34.0481711]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9253e4'),
#   'name': 'RotoHog',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.343938, 33.959799]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92540e'),
#   'name': 'mEgo',
#   'offices': {'address1': '1278 South Beverly Glen'},
#   'coord': {'type': 'Point', 'coordinates': [-118.42749, 34.064491]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9254ca'),
#   'name': 'StreetFire',
#   'offices': {'address1': '12910 Culver Blvd Suite H'},
#   'coord': {'type': 'Point', 'coordinates': [-118.426707, 33.982431]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9254e1'),
#   'name': 'Springbox',
#   'offices': {'address1': '7083 Hollywood Boulevard'},
#   'coord': {'type': 'Point', 'coordinates': [-118.3923578, 34.0065488]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9255c4'),
#   'name': 'RazorGator',
#   'offices': {'address1': '11150 Santa Monica Blvd. Suite 500'},
#   'coord': {'type': 'Point', 'coordinates': [-118.445243, 34.047312]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9255c6'),
#   'name': 'Oversee',
#   'offices': {'address1': '515 S. Flower Street Suite 4400'},
#   'coord': {'type': 'Point', 'coordinates': [-118.256305, 34.051368]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92561c'),
#   'name': 'MetaNotes',
#   'offices': {'address1': 'PO Box 27501'},
#   'coord': {'type': 'Point', 'coordinates': [-118.289065, 34.128046]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925648'),
#   'name': 'PlanJam',
#   'offices': {'address1': '1557 S. Beverly Glen Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.425401, 34.059721]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92564d'),
#   'name': 'E! Entertainment',
#   'offices': {'address1': '5750 Wilshire Boulevard'},
#   'coord': {'type': 'Point', 'coordinates': [-118.3543243, 34.062253]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925662'),
#   'name': 'Jirbo',
#   'offices': {'address1': '149 South Barrington Ave.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.469316, 34.064629]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9256a1'),
#   'name': 'Gorilla Nation Media',
#   'offices': {'address1': '5140 W Goldleaf Circle'},
#   'coord': {'type': 'Point', 'coordinates': [-118.368871, 33.988735]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9256b4'),
#   'name': 'Social Gaming Network',
#   'offices': {'address1': '9570 W. Pico Blvd 3rd Floor'},
#   'coord': {'type': 'Point', 'coordinates': [-122.161523, 37.446823]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9256fb'),
#   'name': 'ePillager',
#   'offices': {'address1': '2809 Ellendale Place #M'},
#   'coord': {'type': 'Point', 'coordinates': [-118.289344, 34.029209]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925702'),
#   'name': 'JuicyCampus',
#   'offices': {'address1': '8939 S. Sepulveda Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.396507, 33.954874]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925755'),
#   'name': 'ALi Corporation',
#   'offices': {'address1': '3130 Wilshire Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.2899533, 34.0618146]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925763'),
#   'name': 'Napster',
#   'offices': {'address1': '9044 Melrose Ave.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.3891962, 34.080772]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925777'),
#   'name': 'AtomicOnline',
#   'offices': {'address1': '5140 W. Goldleaf Circle'},
#   'coord': {'type': 'Point', 'coordinates': [-118.368871, 33.988735]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925787'),
#   'name': 'SEO Intelligence',
#   'offices': {'address1': '530 Molino St.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.23341, 34.041037]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9257ca'),
#   'name': 'Taltopia',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9257f1'),
#   'name': 'SmartRatings',
#   'offices': {'address1': '1964 Westwood Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.434213, 34.047104]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925808'),
#   'name': 'DailyStrength',
#   'offices': {'address1': '12121 wilshire boulevard'},
#   'coord': {'type': 'Point', 'coordinates': [-118.468204, 34.043948]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92582a'),
#   'name': 'CrewedUp',
#   'offices': {'address1': 'PO Box 291583'},
#   'coord': {'type': 'Point', 'coordinates': [-118.292618, 34.089679]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925845'),
#   'name': 'Authenticlick',
#   'offices': {'address1': '5757 Wilshire Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.354605, 34.062504]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92589a'),
#   'name': 'FASTALLEY',
#   'offices': {'address1': '601 N. Spaulding Ave.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.357658, 34.081952]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9258a7'),
#   'name': 'Wedding Channel',
#   'offices': {'address1': '700 South Flower'},
#   'coord': {'type': 'Point', 'coordinates': [-118.2587784, 34.0486806]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9258bc'),
#   'name': 'Causecast',
#   'offices': {'address1': '8800 Venice Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.486889, 34.018349]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9258e2'),
#   'name': 'Magento',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92593b'),
#   'name': 'Mindbox',
#   'offices': {'address1': '350 S. Grand Avenue'},
#   'coord': {'type': 'Point', 'coordinates': [-118.253254, 34.050907]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925986'),
#   'name': 'Brilliant2',
#   'offices': {'address1': '12207 Wilshire Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.46856, 34.043228]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9259a1'),
#   'name': 'Davinci Selectwork',
#   'offices': {'address1': '5340 Alla Road'},
#   'coord': {'type': 'Point', 'coordinates': [-118.4258761, 33.9772881]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9259ff'),
#   'name': 'Shopflick',
#   'offices': {'address1': '10500 W. Pico Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.419067, 34.044939]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925a45'),
#   'name': 'BizRate',
#   'offices': {'address1': '12200 W. Olympic Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.455352, 34.031646]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925ab1'),
#   'name': 'Modern Feed',
#   'offices': {'address1': '818 N. La Brea Ave.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.343791, 34.085749]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925abb'),
#   'name': 'Channel M',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925ae7'),
#   'name': 'FreedomSpeaks',
#   'offices': {'address1': '914 Westwood Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.445257, 34.0634]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925b25'),
#   'name': 'GeoGraffiti',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.264858, 34.05285]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925b6e'),
#   'name': 'The Yucaipa Companies',
#   'offices': {'address1': '9130 Sunset Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.3905856, 34.0905865]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925b6f'),
#   'name': 'OVGuide',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925b8c'),
#   'name': 'FirstString',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925ba3'),
#   'name': 'The Economist Group',
#   'offices': {'address1': '509 North June Street'},
#   'coord': {'type': 'Point', 'coordinates': [-118.334436, 34.080651]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925bd5'),
#   'name': 'Passenger',
#   'offices': {'address1': '5900 Wilshire Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.308943, 34.029956]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925c09'),
#   'name': 'TrafficZ',
#   'offices': {'address1': '11300 W. Olympic Boulevard'},
#   'coord': {'type': 'Point', 'coordinates': [-118.441178, 34.037542]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925c29'),
#   'name': 'SocialVibe',
#   'offices': {'address1': '11388 W Olympic Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.3826743, 34.0815238]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925c2b'),
#   'name': 'LiveAutographs',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925c66'),
#   'name': 'VersaTables',
#   'offices': {'address1': '14105 Avalon Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.265655, 33.903544]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925c6d'),
#   'name': 'GameFly',
#   'offices': {'address1': '11405'},
#   'coord': {'type': 'Point', 'coordinates': [-118.3962622, 33.934558]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925cad'),
#   'name': 'Jamba',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925ce7'),
#   'name': 'Placebase',
#   'offices': {'address1': '821 Traction Ave,'},
#   'coord': {'type': 'Point', 'coordinates': [-118.23497, 34.044931]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925d15'),
#   'name': 'Fabric Interactive',
#   'offices': {'address1': '201 N Westmoreland Ave Suite 106'},
#   'coord': {'type': 'Point', 'coordinates': [-118.288536, 34.0748]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925d4e'),
#   'name': 'MeDeploy',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.3870991, 34.1395597]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925d54'),
#   'name': 'Interpolls',
#   'offices': {'address1': '818 W. 7th St.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.25957, 34.048573]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925d77'),
#   'name': 'ShopIt',
#   'offices': {'address1': '11726 San Vicente Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.46643, 34.05304]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925dd1'),
#   'name': 'simple season',
#   'offices': {'address1': 'P.O. Box 515381 #82145'},
#   'coord': {'type': 'Point', 'coordinates': [-118.255804, 34.039585]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925e17'),
#   'name': 'Attention Span Media',
#   'offices': {'address1': '5225 Wilshire Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.343648, 34.06226]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925f2b'),
#   'name': 'Fandango',
#   'offices': {'address1': '12200 West Olympic Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.455352, 34.031646]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd925fcd'),
#   'name': 'ZipcodeZ',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.4138, 34.05775]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92606a'),
#   'name': 'SceneCaster',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9260b4'),
#   'name': 'J2 Global Communications',
#   'offices': {'address1': '6922 Hollywood Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.3406957, 34.1015548]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926144'),
#   'name': 'Rootdown',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.339502, 34.048545]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926178'),
#   'name': 'Samfind',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.385271, 34.052107]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9261db'),
#   'name': 'Event Innovation',
#   'offices': {'address1': '10100 Santa Monica Boulevard'},
#   'coord': {'type': 'Point', 'coordinates': [-118.416334, 34.061368]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926247'),
#   'name': 'SDI Semiconductor Instruments',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926254'),
#   'name': 'CraveOnline',
#   'offices': {'address1': '5140 Goldleaf Circle'},
#   'coord': {'type': 'Point', 'coordinates': [-118.362442, 33.987978]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92627e'),
#   'name': 'GoodSearch',
#   'offices': {'address1': 'P.O. Box 492176'},
#   'coord': {'type': 'Point', 'coordinates': [-118.488226, 34.086348]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92629c'),
#   'name': 'Tubefilter',
#   'offices': {'address1': '5405 Wilshire Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.350486, 34.070436]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92629f'),
#   'name': 'Skwibble',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9262bb'),
#   'name': 'magnify360',
#   'offices': {'address1': '5933 W. Century Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.38823, 33.946285]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9263a8'),
#   'name': 'Quant the News',
#   'offices': {'address1': '2121 Avenue of the Stars,'},
#   'coord': {'type': 'Point', 'coordinates': [-118.414064, 34.054259]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9263b1'),
#   'name': 'SiteRapture',
#   'offices': {'address1': '5482 Wilshire Blvd. #419'},
#   'coord': {'type': 'Point', 'coordinates': [-118.348198, 34.062262]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926408'),
#   'name': 'Weblocal',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92641d'),
#   'name': 'BakeSpace',
#   'offices': {'address1': '7510 Sunset Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.353624, 34.098028]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926423'),
#   'name': 'Geodelic Systems',
#   'offices': {'address1': '3384 Robertson Place'},
#   'coord': {'type': 'Point', 'coordinates': [-118.488129, 34.005914]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92644d'),
#   'name': 'eVoice',
#   'offices': {'address1': '6922 Hollywood Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.340696, 34.101555]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926479'),
#   'name': 'Tubefilter',
#   'offices': {'address1': '5405 Wilshire Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.350486, 34.070436]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92647c'),
#   'name': 'Skwibble',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926498'),
#   'name': 'magnify360',
#   'offices': {'address1': '5933 W. Century Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.38823, 33.946285]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926585'),
#   'name': 'Quant the News',
#   'offices': {'address1': '2121 Avenue of the Stars,'},
#   'coord': {'type': 'Point', 'coordinates': [-118.414064, 34.054259]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92658e'),
#   'name': 'SiteRapture',
#   'offices': {'address1': '5482 Wilshire Blvd. #419'},
#   'coord': {'type': 'Point', 'coordinates': [-118.348198, 34.062262]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9265e5'),
#   'name': 'Weblocal',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9265fa'),
#   'name': 'BakeSpace',
#   'offices': {'address1': '7510 Sunset Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.353624, 34.098028]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926600'),
#   'name': 'Geodelic Systems',
#   'offices': {'address1': '3384 Robertson Place'},
#   'coord': {'type': 'Point', 'coordinates': [-118.488129, 34.005914]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92662a'),
#   'name': 'eVoice',
#   'offices': {'address1': '6922 Hollywood Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.340696, 34.101555]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9266a3'),
#   'name': 'PeopleJar',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.4104684, 34.1030032]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9266b9'),
#   'name': 'Hollywood Interactive Group',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9266d3'),
#   'name': 'Ratchet',
#   'offices': {'address1': '6285 East Spring Street'},
#   'coord': {'type': 'Point', 'coordinates': [-118.109206, 33.810534]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926722'),
#   'name': 'NOTCOT',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92674a'),
#   'name': 'Total Immersion',
#   'offices': {'address1': '5900 Wilshire Boulevard'},
#   'coord': {'type': 'Point', 'coordinates': [-118.358787, 34.062164]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92676a'),
#   'name': 'FanPrice',
#   'offices': {'address1': '11693 San Vicente Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-122.636071, 38.233786]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926788'),
#   'name': 'SportsGenie',
#   'offices': {'address1': 'PO Box 515381'},
#   'coord': {'type': 'Point', 'coordinates': [-118.2429, 34.0522]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9267e9'),
#   'name': 'Creative Kingdom Animation Studios Film',
#   'offices': {'address1': '1201 West Fifth Street, Suite T-310'},
#   'coord': {'type': 'Point', 'coordinates': [-118.2595569, 34.0541081]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9267ea'),
#   'name': 'Sceneclips',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.26728, 34.05438]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9267f9'),
#   'name': 'Mybandstock',
#   'offices': {'address1': '3475 Ben Lomond Place'},
#   'coord': {'type': 'Point', 'coordinates': [-83.7420579, 42.2802675]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926807'),
#   'name': 'Xtreme Widgets',
#   'offices': {'address1': '4221 Redwood Ave.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.439532, 33.988687]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926808'),
#   'name': 'TVGla',
#   'offices': {'address1': '5340 Alla Road Suite 100'},
#   'coord': {'type': 'Point', 'coordinates': [-118.439532, 33.988687]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926895'),
#   'name': 'MyFreeImplants',
#   'offices': {'address1': '8605 Santa Monica Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.379493, 34.087825]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926940'),
#   'name': 'booksRhere',
#   'offices': {'address1': '3421 Walton Ave'},
#   'coord': {'type': 'Point', 'coordinates': [-118.295117, 34.024817]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926958'),
#   'name': 'The DigiTrust Group',
#   'offices': {'address1': '5757 W. Century Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.382385, 33.946126]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92696d'),
#   'name': 'kidthing',
#   'offices': {'address1': '701 E. 3rd Street'},
#   'coord': {'type': 'Point', 'coordinates': [-118.237811, 34.045845]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92696f'),
#   'name': 'GetBack',
#   'offices': {'address1': '2036 Armacost Ave.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.4536137, 34.0342337]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926980'),
#   'name': 'Vitality',
#   'offices': {'address1': '11755 Wilshire Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.4623627, 34.0485243]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926998'),
#   'name': 'PlayerAuctions',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd92699d'),
#   'name': 'A Unique Presentation',
#   'offices': {'address1': '3675 Dunn Drive'},
#   'coord': {'type': 'Point', 'coordinates': [-118.401729, 34.025386]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9269dc'),
#   'name': 'MovieFlix',
#   'offices': {'address1': '8108 W 4th St.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.365526, 34.070146]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd9269f2'),
#   'name': 'Wild Brain',
#   'offices': {'address1': '9150 Wilshire Ave'},
#   'coord': {'type': 'Point', 'coordinates': [-118.372638, 34.064286]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926a1e'),
#   'name': 'Saltlick Labs',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926a34'),
#   'name': 'Launch 10',
#   'offices': {'address1': '1940 S. Beverly Glen Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.422696, 34.054356]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926a59'),
#   'name': 'ConstructionDeal',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926ab2'),
#   'name': 'PlaceVine',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926ace'),
#   'name': 'Txtms',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed5a020aa91fd926b17'),
#   'name': 'CrownPeak',
#   'offices': {'address1': '5880 West Jefferson Boulevard'},
#   'coord': {'type': 'Point', 'coordinates': [-118.3767176, 34.0240159]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd926ba7'),
#   'name': 'Awareness Technologies',
#   'offices': {'address1': '4640 Admiralty Way'},
#   'coord': {'type': 'Point', 'coordinates': [-118.44097, 33.9812355]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd926c1e'),
#   'name': 'Fonality',
#   'offices': {'address1': '200 Corporate Pointe'},
#   'coord': {'type': 'Point', 'coordinates': [-118.3846632, 33.9874429]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd926c1f'),
#   'name': 'GoGo Lingo',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd926ca9'),
#   'name': 'Creative Artists Agency',
#   'offices': {'address1': '2000 Avenue of the Stars'},
#   'coord': {'type': 'Point', 'coordinates': [-118.4158174, 34.0586832]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd926cd3'),
#   'name': 'Table For Six',
#   'offices': {'address1': '10866 Wilshire Boulevard'},
#   'coord': {'type': 'Point', 'coordinates': [-118.441888, 34.058324]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd926d0c'),
#   'name': 'National Lampoon',
#   'offices': {'address1': '8228 Sunset Boulevard'},
#   'coord': {'type': 'Point', 'coordinates': [-118.3685931, 34.0975446]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd926d2a'),
#   'name': 'Sennari',
#   'offices': {'address1': '12950 Culver Boulevard'},
#   'coord': {'type': 'Point', 'coordinates': [-118.4303427, 33.9782287]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd926d2b'),
#   'name': 'Sennari',
#   'offices': {'address1': '12950 Culver Boulevard'},
#   'coord': {'type': 'Point', 'coordinates': [-118.4303427, 33.9782287]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd926d6c'),
#   'name': 'Broken Knuckles Clothing',
#   'offices': {'address1': '8391 Beverly Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.3729534, 34.0760614]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd926dc2'),
#   'name': 'LeadPoint',
#   'offices': {'address1': '11661 San Vicente Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.464454, 34.054212]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd926e10'),
#   'name': 'Univision',
#   'offices': {'address1': '5999 Center Drive'},
#   'coord': {'type': 'Point', 'coordinates': [-118.3925179, 33.9778907]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd926e34'),
#   'name': 'ReferQuest',
#   'offices': {'address1': '10801 National Blvd., #600'},
#   'coord': {'type': 'Point', 'coordinates': [-118.420346, 34.031222]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd926e7c'),
#   'name': 'Trustworthy',
#   'offices': {'address1': '280 South Beverly Drive, Suite 300'},
#   'coord': {'type': 'Point', 'coordinates': [-118.395346, 34.049246]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd926eb4'),
#   'name': 'KlickSports',
#   'offices': {'address1': '100 Sawtelle Boulevard'},
#   'coord': {'type': 'Point', 'coordinates': [-118.445584, 34.0431973]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd926fb4'),
#   'name': 'Boom Studios',
#   'offices': {'address1': '6310 San Vicente Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.367703, 34.060523]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd926fe3'),
#   'name': 'Link Gateway',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd927013'),
#   'name': 'TechForward',
#   'offices': {'address1': '6080 Center Dr.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.613385, 34.146503]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd92706e'),
#   'name': 'Mobile Messenger',
#   'offices': {'address1': '6601 Center Dr W,'},
#   'coord': {'type': 'Point', 'coordinates': [-118.393979, 33.979956]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd9270ca'),
#   'name': 'ABCO TECHNOLOGY',
#   'offices': {'address1': '6733 Sepulveda Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.394889, 33.978825]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd927106'),
#   'name': 'eModeration',
#   'offices': {'address1': '15303 Ventura Blvd, Suite 900,'},
#   'coord': {'type': 'Point', 'coordinates': [-118.4662511, 34.1538216]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd92717c'),
#   'name': "Blip'd",
#   'offices': {'address1': '8391 Beverly Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.3729534, 34.0760614]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd92721c'),
#   'name': 'Jobspring Partners',
#   'offices': {'address1': '10990 Wilshire Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.447078, 34.057346]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd927224'),
#   'name': 'Workbridge Associates',
#   'offices': {'address1': '10990 Wilshire Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.447078, 34.057346]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd92738f'),
#   'name': 'Ranker',
#   'offices': {'address1': '6420 Wilshire Blvd.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.325739, 34.1012181]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd927396'),
#   'name': 'Epsilon Concepts',
#   'offices': {'address1': '1010 Wilshire Blvd.; Suite 1101'},
#   'coord': {'type': 'Point', 'coordinates': [-118.262233, 34.051508]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd9274a2'),
#   'name': 'Silvatar Media',
#   'offices': {'address1': '1800 N. New Hampshire Ave'},
#   'coord': {'type': 'Point', 'coordinates': [-118.293316, 34.1036353]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd9274ba'),
#   'name': 'Global Digital Media Xchange',
#   'offices': {'address1': '5432 W. 102nd Street'},
#   'coord': {'type': 'Point', 'coordinates': [-118.374904, 33.943108]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd9274e8'),
#   'name': 'Sensis',
#   'offices': {'address1': '811 W. 7th Street'},
#   'coord': {'type': 'Point', 'coordinates': [-118.2593181, 34.0490571]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd927563'),
#   'name': 'Huge',
#   'offices': {'address1': '6100 Wilshire Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.373614, 34.167304]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd9276be'),
#   'name': 'Yoostar',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd9276eb'),
#   'name': 'WebPurify',
#   'offices': {'address1': '2029 Century Park East'},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd9276fd'),
#   'name': 'eblizz',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.4920896, 34.0163012]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd927702'),
#   'name': 'SchoolRack',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.4221519, 34.0386656]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd927762'),
#   'name': 'Cocodot',
#   'offices': {'address1': '8052 W. 3rd Street'},
#   'coord': {'type': 'Point', 'coordinates': [-118.375698, 34.104692]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd927899'),
#   'name': 'Moviepilot',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.2436849, 34.0522342]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd9278af'),
#   'name': 'High Density Networks',
#   'offices': {'address1': '900 N. Alameda St'},
#   'coord': {'type': 'Point', 'coordinates': [-118.235338, 34.058101]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd9278c4'),
#   'name': 'ITTAGS',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd9278c5'),
#   'name': 'Iteego',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd927930'),
#   'name': 'Global Fitness Media',
#   'offices': {'address1': '11611 San Vicente Blvd., Suite 850'},
#   'coord': {'type': 'Point', 'coordinates': [-118.462876, 34.054318]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd927995'),
#   'name': 'AECOM Technology',
#   'offices': {'address1': '555 South Flower Street'},
#   'coord': {'type': 'Point', 'coordinates': [-118.2568615, 34.0507962]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd927b17'),
#   'name': 'Culture Jam',
#   'offices': {'address1': '2434 Lincoln Blvd'},
#   'coord': {'type': 'Point', 'coordinates': [-118.4660597, 34.0137151]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd927b69'),
#   'name': 'Pipit Interactive',
#   'offices': {'address1': '1014 Amherst Ave.'},
#   'coord': {'type': 'Point', 'coordinates': [-118.47036, 34.045499]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd927ba3'),
#   'name': 'Top Rated Website Designers',
#   'offices': {'address1': ''},
#   'coord': {'type': 'Point', 'coordinates': [-118.3987842, 33.9933257]}},
#  {'_id': ObjectId('5fb00ed6a020aa91fd927bbe'),
#   'name': 'IVR Technologies',
#   'offices': {'address1': '555 West Fifth Street'},
#   'coord': {'type': 'Point', 'coordinates': [-118.253161, 34.050066]}}]

# %%
name = []
latlng = []
latlng_str = []
for i in range(166):
    name.append(res[i]['name'])
    latlng.append(res[i]['coord']['coordinates'][::-1])

# %%
df = pd.DataFrame()
df['name'] = name
df['office_lst'] = latlng
for lst in latlng:
    latlng_str.append(f"{lst[0]},{lst[1]}")
df['office_str'] = latlng_str
df
# Out:
#                             name                  office_lst  \
# 0                          Helio    [34.057498, -118.446596]
# 1                        Stickam    [34.051409, -118.254558]
# 2                         TripUp    [34.052187, -118.243425]
# 3                      ScanScout    [34.050887, -118.459995]
# 4                      WebbAlert    [34.052187, -118.243425]
# ..                           ...                         ...
# 161             AECOM Technology  [34.0507962, -118.2568615]
# 162                  Culture Jam  [34.0137151, -118.4660597]
# 163            Pipit Interactive     [34.045499, -118.47036]
# 164  Top Rated Website Designers  [33.9933257, -118.3987842]
# 165             IVR Technologies    [34.050066, -118.253161]
#
#                   office_str
# 0      34.057498,-118.446596
# 1      34.051409,-118.254558
# 2      34.052187,-118.243425
# 3      34.050887,-118.459995
# 4      34.052187,-118.243425
# ..                       ...
# 161  34.0507962,-118.2568615
# 162  34.0137151,-118.4660597
# 163     34.045499,-118.47036
# 164  33.9933257,-118.3987842
# 165    34.050066,-118.253161
#
# [166 rows x 3 columns]

# %%
df.to_csv('offices_LA.csv')
